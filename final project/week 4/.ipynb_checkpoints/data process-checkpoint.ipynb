# %%
import requests

# %%
r = requests.get("https://www.opentable.com/best-toronto-ontario-restaurants?topic=f9d537b4-fe3f-4f8b-8c7c-e0e0d21829e3&corrid=928ecc40-94b6-4cbe-9b6a-6394af1a4141")

# %%
r.text
# Out:
# '           <!DOCTYPE html><html lang="en"><head><meta charset="utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=9; IE=8; IE=7; IE=EDGE"/> <title>Restaurant Reservation Availability</title>    <meta  name="robots" content="index,follow" > </meta><link  rel="canonical" href="https://www.opentable.com/best-toronto-ontario-restaurants" > </link>                 <link rel="alternate" hreflang="en-US" href="https://www.opentable.com/best-toronto-ontario-restaurants"/> \n        <link rel="alternate" hreflang="fr-US" href="https://www.opentable.com/best-toronto-ontario-restaurants?lang=fr"/> \n        <link rel="alternate" hreflang="de-US" href="https://www.opentable.com/best-toronto-ontario-restaurants?lang=de"/> \n        <link rel="alternate" hreflang="es-US" href="https://www.opentable.com/best-toronto-ontario-restaurants?lang=es"/> \n        <link rel="alternate" hreflang="ja-US" href="https://www.opentable.com/best-toronto-ontario-restaurants?lang=ja"/> \n        <link rel="alt
# ...

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(r.text,'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=9; IE=8; IE=7; IE=EDGE" http-equiv="X-UA-Compatible"/>
#   <title>
#    Restaurant Reservation Availability
#   </title>
#   <meta content="index,follow" name="robots"/>
#   <link href="https://www.opentable.com/best-toronto-ontario-restaurants" rel="canonical"/>
#   <link href="https://www.opentable.com/best-toronto-ontario-restaurants" hreflang="en-US" rel="alternate"/>
#   <link href="https://www.opentable.com/best-toronto-ontario-restaurants?lang=fr" hreflang="fr-US" rel="alternate"/>
#   <link href="https://www.opentable.com/best-toronto-ontario-restaurants?lang=de" hreflang="de-US" rel="alternate"/>
#   <link href="https://www.opentable.com/best-toronto-ontario-restaurants?lang=es" hreflang="es-US" rel="alternate"/>
#   <link href="https://www.opentable.com/best-toronto-ontario-restaurants?lang=ja" hreflang="ja-US" rel="alternate"/>
# ...

# %%
raw = soup.findAll('li',class_='result content-section-list-row cf with-times')

# %%
raw
# Out:
# [<li class="result content-section-list-row cf with-times" data-id="0" data-index="1" data-is-marketed="true" data-is-promoted="undefined" data-lat="-72.2443" data-lon="-15.2881" data-offers="" data-restaurant-availability-token="" data-rid="1507"><div class="rest-row with-image"> <div class="rest-row-image"> <a href="undefined" onclick="OT.BestAnalytics.logRestaurantVisit(1507)" target="_blank"><img alt="photo of 1149 haag restaurant" class="lazy rest-image" data-src="//media.otstatic.com/search-result-node/images/no-image.png" src="//media.otstatic.com/search-result-node/images/no-image.png"/></a> </div> <div class="rest-row-info"><div class="rest-row-header"> <a class="rest-row-name rest-name " href="undefined" onclick="OT.BestAnalytics.logRestaurantVisit(1507)" target="_blank"><span class="rest-row-name-text">1149 Haag</span> </a> </div> <div class="rest-row-meta rest-row-meta-grid flex-row-justify"><div class="flex-row-justify"> <div class="rest-row-review"> <div class="review-c
# ...

# %%
raw[0]
# Out:
# <li class="result content-section-list-row cf with-times" data-id="0" data-index="1" data-is-marketed="true" data-is-promoted="undefined" data-lat="-72.2443" data-lon="-15.2881" data-offers="" data-restaurant-availability-token="" data-rid="1507"><div class="rest-row with-image"> <div class="rest-row-image"> <a href="undefined" onclick="OT.BestAnalytics.logRestaurantVisit(1507)" target="_blank"><img alt="photo of 1149 haag restaurant" class="lazy rest-image" data-src="//media.otstatic.com/search-result-node/images/no-image.png" src="//media.otstatic.com/search-result-node/images/no-image.png"/></a> </div> <div class="rest-row-info"><div class="rest-row-header"> <a class="rest-row-name rest-name " href="undefined" onclick="OT.BestAnalytics.logRestaurantVisit(1507)" target="_blank"><span class="rest-row-name-text">1149 Haag</span> </a> </div> <div class="rest-row-meta rest-row-meta-grid flex-row-justify"><div class="flex-row-justify"> <div class="rest-row-review"> <div class="review-co
# ...

# %%
import re

# %%
list = []

# %%
for each in raw:
    reg1 = <span class="rest-row-name-text">.*?<\/span>
    reg2 = data-lat=\".*?\" 
    reg3 =data-lon=\".*?\"
    name = re.find(reg1)
